# %%
import requests

# %%
user  = requests.get('https://api.github.com/users/Upsetjojos2')

# %%
user
# Out:
# <Response [200]>

# %%
user.status_code
# Out:
# 200

# %%
user.url
# Out:
# 'https://api.github.com/users/Upsetjojos2'

# %%
user.json()
# Out:
# {'login': 'Upsetjojos2',
#  'id': 119707617,
#  'node_id': 'U_kgDOByKX4Q',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/119707617?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Upsetjojos2',
#  'html_url': 'https://github.com/Upsetjojos2',
#  'followers_url': 'https://api.github.com/users/Upsetjojos2/followers',
#  'following_url': 'https://api.github.com/users/Upsetjojos2/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Upsetjojos2/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Upsetjojos2/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Upsetjojos2/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Upsetjojos2/orgs',
#  'repos_url': 'https://api.github.com/users/Upsetjojos2/repos',
#  'events_url': 'https://api.github.com/users/Upsetjojos2/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Upsetjojos2/received_events',
# ...

# %%
nome=user.json()['name']
nome_usuario=user.json()['login']
repositorios=user.json()['public_repos']
data_criacao_dados=user.json()['created_at']

print(f'Nome: {nome}')
print(f'Nome de usuário: {nome_usuario}')
print(f'Número de repositórios públicos: {repositorios}')
print(f'Data de criação dos dados: {data_criacao_dados}')
# Out:
# Nome: Gabriel Eng dados
# Nome de usuário: Upsetjojos2
# Número de repositórios públicos: 1
# Data de criação dos dados: 2022-12-02T22:10:29Z

# %% [markdown]
# Atividade 2

# %%
import requests

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_url}/users/{owner}/repos'

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
len(repos_list)
# Out:
# 5

# %%
import requests

username = 'amzn'
url = f"https://api.github.com/users/{username}/followers"

response = requests.get(url, headers=headers)
followers = response.json()

# %%
page_num = 1
followers_list = []

while True:
    url_page = f"{url}?page={page_num}"
    response = requests.get(url_page, headers=headers)
    data = response.json()
    
    if not data:
        break
    
    followers_list.append(data)
